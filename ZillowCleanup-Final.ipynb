# %%
import pandas as pd
# figure out sqlite
# table plus

# %%
pd.read_sql_table?

# %%
#df1=pd.read_csv('Resources/City_Zhvi_1bedroom.csv')
#df2=pd.read_csv('Resources/City_Zhvi_2bedroom.csv')
df3=pd.read_csv('Resources/City_Zhvi_3bedroom.csv')
df4=pd.read_csv('Resources/City_Zhvi_4bedroom.csv')
df5=pd.read_csv('Resources/City_Zhvi_5BedroomOrMore.csv')

# %%
#df = pd.concat([df1,df2,df3,df4,df5], ignore_index=True)
df = pd.concat([df3,df4,df5], ignore_index=True)

# %%
df.head()
# Out:
#    Bedrooms  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0         3      6181         0     New York       City        NY    NY
# 1         3     12447         1  Los Angeles       City        CA    CA
# 2         3     39051         2      Houston       City        TX    TX
# 3         3     17426         3      Chicago       City        IL    IL
# 4         3      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1/31/1996  ...  \
# 0       New York-Newark-Jersey City       Queens County   206340.0  ...
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County   182221.0  ...
# 2  Houston-The Woodlands-Sugar Land       Harris County    84660.0  ...
# 3          Chicago-Naperville-Elgin         Cook County   123550.0  ...
# 4         San Antonio-New Braunfels        Bexar County    86633.0  ...
#
#    6/30/2019  7/31/2019  8/31/2019  9/30/2019  10/31/2019  11/30/2019  \
# ...

# %%
df.dtypes
# Out:
# Bedrooms       int64
# RegionID       int64
# SizeRank       int64
# RegionName    object
# RegionType    object
#                ...
# 11/30/2019     int64
# 12/31/2019     int64
# 1/31/2020      int64
# 2/29/2020      int64
# 3/31/2020      int64
# Length: 300, dtype: object

# %%
df.set_index(['Bedrooms','RegionID','SizeRank','RegionName','RegionType','StateName','State','Metro','CountyName'], inplace=True)

# %%
df = df.stack().reset_index()

# %%
df
# Out:
#           Bedrooms  RegionID  SizeRank      RegionName RegionType StateName  \
# 0                3      6181         0        New York       City        NY
# 1                3      6181         0        New York       City        NY
# 2                3      6181         0        New York       City        NY
# 3                3      6181         0        New York       City        NY
# 4                3      6181         0        New York       City        NY
# ...            ...       ...       ...             ...        ...       ...
# 14290010         5     50522     29449  Oriskany Falls       City        NY
# 14290011         5     50522     29449  Oriskany Falls       City        NY
# 14290012         5     50522     29449  Oriskany Falls       City        NY
# 14290013         5     50522     29449  Oriskany Falls       City        NY
# 14290014         5     50522     29449  Oriskany Falls       City        NY
#
# ...

# %%
df.rename(columns = {'level_9':'Date', df.columns[10]:'Price'}, inplace = True)

# %%
df
# Out:
#           Bedrooms  RegionID  SizeRank      RegionName RegionType StateName  \
# 0                3      6181         0        New York       City        NY
# 1                3      6181         0        New York       City        NY
# 2                3      6181         0        New York       City        NY
# 3                3      6181         0        New York       City        NY
# 4                3      6181         0        New York       City        NY
# ...            ...       ...       ...             ...        ...       ...
# 14290010         5     50522     29449  Oriskany Falls       City        NY
# 14290011         5     50522     29449  Oriskany Falls       City        NY
# 14290012         5     50522     29449  Oriskany Falls       City        NY
# 14290013         5     50522     29449  Oriskany Falls       City        NY
# 14290014         5     50522     29449  Oriskany Falls       City        NY
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           Bedrooms  RegionID  SizeRank      RegionName RegionType StateName  \
# 0                3      6181         0        New York       City        NY
# 1                3      6181         0        New York       City        NY
# 2                3      6181         0        New York       City        NY
# 3                3      6181         0        New York       City        NY
# 4                3      6181         0        New York       City        NY
# ...            ...       ...       ...             ...        ...       ...
# 14290010         5     50522     29449  Oriskany Falls       City        NY
# 14290011         5     50522     29449  Oriskany Falls       City        NY
# 14290012         5     50522     29449  Oriskany Falls       City        NY
# 14290013         5     50522     29449  Oriskany Falls       City        NY
# 14290014         5     50522     29449  Oriskany Falls       City        NY
#
# ...

# %%
tn_only = df['State'] == 'TN'
df_tn = df.loc[tn_only]
df_tn
# Out:
#           Bedrooms  RegionID  SizeRank RegionName RegionType StateName State  \
# 7072             3     32811        25    Memphis       City        TN    TN
# 7073             3     32811        25    Memphis       City        TN    TN
# 7074             3     32811        25    Memphis       City        TN    TN
# 7075             3     32811        25    Memphis       City        TN    TN
# 7076             3     32811        25    Memphis       City        TN    TN
# ...            ...       ...       ...        ...        ...       ...   ...
# 14260113         5     10515     29366     Braden       City        TN    TN
# 14260114         5     10515     29366     Braden       City        TN    TN
# 14260115         5     10515     29366     Braden       City        TN    TN
# 14260116         5     10515     29366     Braden       City        TN    TN
# 14260117         5     10515     29366     Braden       City        TN    TN
#
# ...

# %%
df_tn.dtypes
# Out:
# Bedrooms        int64
# RegionID        int64
# SizeRank        int64
# RegionName     object
# RegionType     object
# StateName      object
# State          object
# Metro          object
# CountyName     object
# Date           object
# Price         float64
# dtype: object

# %%
df_tn['Date']= pd.to_datetime(df_tn['Date'])
# Out:
# C:\Users\16153\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_tn.dtypes
# Out:
# Bedrooms               int64
# RegionID               int64
# SizeRank               int64
# RegionName            object
# RegionType            object
# StateName             object
# State                 object
# Metro                 object
# CountyName            object
# Date          datetime64[ns]
# Price                float64
# dtype: object

# %%
df_tn_date = df_tn.loc[(df_tn['Date'] >= '2001-01-01')]

# %%
df_tn_date
# Out:
#           Bedrooms  RegionID  SizeRank RegionName RegionType StateName State  \
# 7132             3     32811        25    Memphis       City        TN    TN
# 7133             3     32811        25    Memphis       City        TN    TN
# 7134             3     32811        25    Memphis       City        TN    TN
# 7135             3     32811        25    Memphis       City        TN    TN
# 7136             3     32811        25    Memphis       City        TN    TN
# ...            ...       ...       ...        ...        ...       ...   ...
# 14260113         5     10515     29366     Braden       City        TN    TN
# 14260114         5     10515     29366     Braden       City        TN    TN
# 14260115         5     10515     29366     Braden       City        TN    TN
# 14260116         5     10515     29366     Braden       City        TN    TN
# 14260117         5     10515     29366     Braden       City        TN    TN
#
# ...

# %%
df_tn.isna().sum()
# Out:
# Bedrooms          0
# RegionID          0
# SizeRank          0
# RegionName        0
# RegionType        0
# StateName         0
# State             0
# Metro         90088
# CountyName        0
# Date              0
# Price             0
# dtype: int64

# %%
df_tn = df_tn.drop(columns=['RegionID','SizeRank','RegionType','StateName','State','Metro','CountyName'])
df_tn
# Out:
#           Bedrooms RegionName       Date     Price
# 7072             3    Memphis 1996-01-31   72962.0
# 7073             3    Memphis 1996-02-29   73084.0
# 7074             3    Memphis 1996-03-31   73237.0
# 7075             3    Memphis 1996-04-30   73552.0
# 7076             3    Memphis 1996-05-31   73906.0
# ...            ...        ...        ...       ...
# 14260113         5     Braden 2019-11-30  266558.0
# 14260114         5     Braden 2019-12-31  269833.0
# 14260115         5     Braden 2020-01-31  271472.0
# 14260116         5     Braden 2020-02-29  276641.0
# 14260117         5     Braden 2020-03-31  281210.0
#
# [335061 rows x 4 columns]

# %%
df_tn.reset_index(drop=True, inplace=True)
df_tn
# Out:
#         Bedrooms RegionName       Date     Price
# 0              3    Memphis 1996-01-31   72962.0
# 1              3    Memphis 1996-02-29   73084.0
# 2              3    Memphis 1996-03-31   73237.0
# 3              3    Memphis 1996-04-30   73552.0
# 4              3    Memphis 1996-05-31   73906.0
# ...          ...        ...        ...       ...
# 335056         5     Braden 2019-11-30  266558.0
# 335057         5     Braden 2019-12-31  269833.0
# 335058         5     Braden 2020-01-31  271472.0
# 335059         5     Braden 2020-02-29  276641.0
# 335060         5     Braden 2020-03-31  281210.0
#
# [335061 rows x 4 columns]

# %%
df_tn.to_csv('Resources/combined_zillow_final.csv',index=True)

# %%
# use predict method predict(X) X=all values as a list 
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.predict
